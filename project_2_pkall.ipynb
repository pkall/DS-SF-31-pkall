# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer: 400

# %% [markdown]
# #### Question 2. Create a summary table

# %%
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: GRE scores are measured on a much wider range than GPA is.

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_raw.isnull().sum()
# Out:
# admit       0
# gre         2
# gpa         2
# prestige    1
# dtype: int64

# %%
df_raw = df_raw.dropna()

# %%
df_raw.isnull().sum()
# Out:
# admit       0
# gre         0
# gpa         0
# prestige    0
# dtype: int64

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %% [markdown]
# Answer: I checked using df_raw.isnull().sum()

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
sb.boxplot(x=df_raw.gre, data = df_raw)

# %%
sb.boxplot(x="gpa", data = df_raw)

# %% [markdown]
# #### Question 7. What do these plots show?

# %% [markdown]
# Answer: They show the interquartile range of the distribution of each variable, the full extent of the distribution (the "whiskers"), and any outliers using a function of the interquartile range.

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
sb.distplot(df_raw.admit)

# %%
sb.distplot(df_raw.gre)

# %%
sb.distplot(df_raw.gpa)

# %%
sb.distplot(df_raw.prestige)

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: The two continuous variables appear to be fairly normal, some additional correction might be worthwhile.

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer: I do not think either of the continuous variables needs correction. However, if we felt they did, we might try taking the log of each of them. See below for sample code:

# %%
#df_raw["gre"] = np.log(df_raw.gre)

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
sb.heatmap(df_raw.corr());

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: GRE and GPA scores are fairly correlated, which is not completely unexpected as both are intended to be measures of academic performance.

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer: First I would examine the rate of admission into graduate school based on the prestige of undergraduate schools. Then I would see if those rates (which I would expect to be higher for more prestigous schools) hold up when GRE and GPA scores are controlled for.

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: That more prestigous undergraduate schools have a stastically significant impact on admissions rates into graduate school even when controlling for GRE and GPA scores.

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
